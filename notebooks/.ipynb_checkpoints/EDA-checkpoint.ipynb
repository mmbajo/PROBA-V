# %%
import sys
sys.path.insert(0, '../utils')

from dataGenerator import *

# %reload_ext autoreload
# %autoreload 2

# %%
arrayDir = '/home/mark/DataBank/PROBA-V-CHKPT/dataset'
rawDataDir = '/home/mark/DataBank/probav_data'
band = 'NIR'

# %%
loadAndSaveRawData(rawDataDir, arrayDir, 'NIR', isGrayScale=True, isTrainData=True)
loadAndSaveRawData(rawDataDir, arrayDir, 'RED', isGrayScale=True, isTrainData=True)
loadAndSaveRawData(rawDataDir, arrayDir, 'NIR', isGrayScale=True, isTrainData=False)
loadAndSaveRawData(rawDataDir, arrayDir, 'RED', isGrayScale=True, isTrainData=False)

# %%
TRAIN, TEST = loadData(arrayDir, band)

# Process the train dataset
allImgLR, allMskLR, allImgHR, allMskHR = TRAIN
allImgMskLR = registerImages(allImgLR, allMskLR)  # np.ma.masked_array
allImgMskHR = convertToMaskedArray(allImgHR, allMskHR)  # np.ma.masked_array
# Out:
# [ INFO ] Registering LR images         : 100%|██████████| 566/566 [03:42<00:00,  2.55it/s]

# %%
trmImgMskLR, trmImgMskHR = removeCorruptedTrainImageSets(allImgMskLR, allImgMskHR, clarityThreshold=0.7)
trmImgMskLR = pickClearLRImgsPerImgSet(trmImgMskLR, numImgToPick=9, clarityThreshold=0.7)

# Process the test dataset
allImgLRTest, allMskLRTest = TEST
allImgMskLRTest = registerImages(allImgLRTest, allMskLRTest)  # np.ma.masked_array
trmImgMskLRTest = removeCorruptedTrainImageSets(allImgMskLRTest, clarityThreshold=0.7)
trmImgMskLRTest = pickClearLRImgsPerImgSet(trmImgMskLRTest, numImgToPick=9, clarityThreshold=0.7)
# Out:
# [ INFO ] Removing corrupted ImageSets  :   0%|          | 0/566 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# [ INFO ] Removing corrupted ImageSets  : 100%|██████████| 566/566 [00:00<00:00, 3922.83it/s]
#
#
#
#
#
#
#
#
# [ INFO ] Picking top 9 clearest images :   0%|          | 0/132 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# [ INFO ] Picking top 9 clearest images : 100%|██████████| 132/132 [00:00<00:00, 1135.89it/s]
#
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   0%|          | 0/566 [00:00<?, ?it/s]
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# [ INFO ] Registering LR images         :   0%|          | 1/566 [00:00<03:47,  2.49it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   0%|          | 2/566 [00:00<03:15,  2.88it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   1%|          | 3/566 [00:01<03:25,  2.74it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   1%|          | 4/566 [00:01<03:24,  2.75it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   1%|          | 5/566 [00:01<03:28,  2.69it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   1%|          | 6/566 [00:02<03:10,  2.94it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   1%|          | 7/566 [00:02<03:21,  2.77it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   1%|▏         | 8/566 [00:02<03:36,  2.58it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   2%|▏         | 9/566 [00:03<03:38,  2.55it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   2%|▏         | 10/566 [00:03<03:45,  2.46it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   2%|▏         | 11/566 [00:04<04:23,  2.10it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   2%|▏         | 12/566 [00:04<04:27,  2.07it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   2%|▏         | 13/566 [00:05<03:44,  2.46it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   2%|▏         | 14/566 [00:05<03:32,  2.60it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   3%|▎         | 15/566 [00:05<03:30,  2.62it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   3%|▎         | 16/566 [00:06<03:19,  2.76it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   3%|▎         | 17/566 [00:06<03:53,  2.35it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   3%|▎         | 18/566 [00:06<03:26,  2.65it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   3%|▎         | 19/566 [00:07<03:22,  2.70it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   4%|▎         | 20/566 [00:07<03:11,  2.86it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   4%|▎         | 21/566 [00:08<03:49,  2.38it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   4%|▍         | 22/566 [00:08<03:45,  2.41it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   4%|▍         | 23/566 [00:08<03:35,  2.52it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   4%|▍         | 24/566 [00:09<04:07,  2.19it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   4%|▍         | 25/566 [00:09<03:54,  2.30it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   5%|▍         | 26/566 [00:10<04:04,  2.21it/s]
#
#
#
#
#
#
#
# [ INFO ] Registering LR images         :   5%|▍         | 27/566 [00:10<03:57,  2.27it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-95527b08f316> in <module>
#       4 # Process the test dataset
#       5 allImgLRTest, allMskLRTest = TEST
# ----> 6 allImgMskLRTest = registerImages(allImgLRTest, allMskLRTest)  # np.ma.masked_array
#       7 trmImgMskLRTest = removeCorruptedTrainImageSets(allImgMskLRTest, clarityThreshold=0.7)
#       8 trmImgMskLRTest = pickClearLRImgsPerImgSet(trmImgMskLRTest, numImgToPick=7, clarityThreshold=0.7)
#
# ~/PROBA-V/utils/dataGenerator.py in registerImages(allImgLR, allMskLR)
#     149     #      '[ INFO ] Loading LR masks and dumping  '
#     150     desc = '[ INFO ] Registering LR images         '
# --> 151     return np.array([registerImagesInSet(allImgLR[i], allMskLR[i]) for i in tqdm(range(allImgLR.shape[0]), desc=desc)])
#     152
#     153
#
# ~/PROBA-V/utils/dataGenerator.py in <listcomp>(.0)
#     149     #      '[ INFO ] Loading LR masks and dumping  '
#     150     desc = '[ INFO ] Registering LR images         '
# --> 151     return np.array([registerImagesInSet(allImgLR[i], allMskLR[i]) for i in tqdm(range(allImgLR.shape[0]), desc=desc)])
#     152
#     153
#
# ~/PROBA-V/utils/dataGenerator.py in registerImagesInSet(imgLR, mskLR)
#     169     referImg = imgLR[np.argmax([np.count_nonzero(msk) for msk in mskLR])]
#     170     for i, (img, msk) in enumerate(zip(imgLR, mskLR)):
# --> 171         regImg, regMsk = registerFrame(img, msk.astype(bool), referImg)
#     172         mskdArray = np.expand_dims(np.ma.masked_array(regImg, mask=regMsk), axis=0)
#     173         if i == 0:
#
# ~/PROBA-V/utils/dataGenerator.py in registerFrame(img, msk, referenceImg)
#     190     regMsk: np.ndarray[channel, height, width]
#     191     '''
# --> 192     shiftArray = masked_register_translation(referenceImg, img, msk)
#     193     regImg = shift(img, shiftArray, mode='reflect')
#     194     regMsk = shift(msk, shiftArray, mode='constant', cval=0)
#
# ~/.local/lib/python3.6/site-packages/skimage/feature/masked_register_translation.py in masked_register_translation(src_image, target_image, src_mask, target_mask, overlap_ratio)
#      79     xcorr = cross_correlate_masked(target_image, src_image, target_mask,
#      80                                    src_mask, axes=(0, 1), mode='full',
# ---> 81                                    overlap_ratio=overlap_ratio)
#      82
#      83     # Generalize to the average of multiple equal maxima
#
# ~/.local/lib/python3.6/site-packages/skimage/feature/masked_register_translation.py in cross_correlate_masked(arr1, arr2, m1, m2, mode, axes, overlap_ratio)
#     199     # Locations with high overlap should not be taken into account.
#     200     number_overlap_masked_px = np.real(
# --> 201         ifft(rotated_moving_mask_fft * fixed_mask_fft))
#     202     number_overlap_masked_px[:] = np.round(number_overlap_masked_px)
#     203     number_overlap_masked_px[:] = np.fmax(number_overlap_masked_px, eps)
#
# ~/.local/lib/python3.6/site-packages/scipy/fft/_backend.py in __ua_function__(method, args, kwargs)
#      21         if fn is None:
#      22             return NotImplemented
# ---> 23         return fn(*args, **kwargs)
#      24
#      25
#
# ~/.local/lib/python3.6/site-packages/scipy/fft/_pocketfft/basic.py in c2cn(forward, x, s, axes, norm, overwrite_x, workers)
#     159     out = (tmp if overwrite_x and tmp.dtype.kind == 'c' else None)
#     160
# --> 161     return pfft.c2c(tmp, axes, forward, norm, out, workers)
#     162
#     163
#
# KeyboardInterrupt:

# %%
allImgLR[0][0].shape

# %%
allImgMskHR.shape

# %%
allImgMskLR.shape

# %%
type(allImgMskLR)

# %%
x = np.array([np.array(a) for a in allImgMskLR])

# %%
x[0][0].shape

# %%
band = 'NIR'
TRAIN, TEST = loadData(arrayDir, band)

# Process the train dataset
allImgLR, allMskLR, allImgHR, allMskHR = TRAIN

# %%
for i in range(len(allImgLR)):
    print(len(allImgLR[i]))

# %%
allImgLR.shape

# %%
allImgMskLR[1].shape

# %%
trmImgMskLR.shape
# Out:
# (132, 9, 1, 128, 128)

# %%
trmImgMskLR.shape
# Out:
# (132, 9, 1, 128, 128)
